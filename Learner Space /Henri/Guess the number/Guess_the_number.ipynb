# %%
import random

chiffre_a_trouver = random.randint(0, 100)
name = input("Veuillez insérer votre nom: ")

for i in range(10):
  guess = input("Deviner le nombre entre 0 et 100: ")
  while not guess.isdigit() or int(guess) <= 0 or int(guess) >= 100 :
    guess = input("Veuillez introduire un NOMBRE entre 0 et 100: ")
  if int(guess) == chiffre_a_trouver:
    print(f"BRAVOOOO {name}!!! Tu as trouvé le nombre qui était", chiffre_a_trouver, "en", i+1, "rounds")
    break
  elif int(guess) > chiffre_a_trouver:
    print("Le chiffre à trouvé est plus petit que le votre")
  elif int(guess) < chiffre_a_trouver:
    print("Le chiffre à trouvé est plus grand que le votre")

if int(guess) != chiffre_a_trouver:
  print(f"Dommage {name}... Tu n'as pas trouver le chiffre a trouver, c'était", chiffre_a_trouver)
# Out:
# Veuillez insérer votre nom: Henri
# Deviner le nombre entre 0 et 100: 5à
# Veuillez introduire un NOMBRE entre 0 et 100: 50
# Le chiffre à trouvé est plus grand que le votre
# Deviner le nombre entre 0 et 100: 75
# Le chiffre à trouvé est plus grand que le votre
# Deviner le nombre entre 0 et 100: 90
# Le chiffre à trouvé est plus petit que le votre
# Deviner le nombre entre 0 et 100: 83
# Le chiffre à trouvé est plus grand que le votre
# Deviner le nombre entre 0 et 100: 86
# Le chiffre à trouvé est plus grand que le votre
# Deviner le nombre entre 0 et 100: 88
# Le chiffre à trouvé est plus petit que le votre
# Deviner le nombre entre 0 et 100: 87
# BRAVOOOO Henri!!! Vous avez trouver le nombre qui était 87 en 7 rounds
